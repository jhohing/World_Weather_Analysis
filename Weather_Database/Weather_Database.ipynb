# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities= []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 717

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descr = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_descr})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | mecca
# Processing Record 4 of Set 1 | sao filipe
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | abony
# Processing Record 7 of Set 1 | hasaki
# Processing Record 8 of Set 1 | nome
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | vestmannaeyjar
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | menongue
# Processing Record 15 of Set 1 | tilichiki
# Processing Record 16 of Set 1 | orlik
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | calamar
# Processing Record 19 of Set 1 | vila velha
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | baykit
# Processing Record 23 of Set 1 | okha
# Processing Record 24 of Set 1 | los algarrobos
# Processing Record 25 of Set 1 | kajaani
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | mahanoro
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | ahipara
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | bethel
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | sitka
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | yar-sale
# Processing Record 43 of Set 1 | ostrovnoy
# Processing Record 44 of Set 1 | namibe
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | eldikan
# City not found. Skipping...
# Processing Record 48 of Set 1 | yeniseysk
# Processing Record 49 of Set 1 | tuatapere
# Processing Record 50 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | punta cardon
# Processing Record 5 of Set 2 | lagoa
# Processing Record 6 of Set 2 | abu kamal
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | tianpeng
# Processing Record 9 of Set 2 | vostok
# Processing Record 10 of Set 2 | tiksi
# Processing Record 11 of Set 2 | langsa
# Processing Record 12 of Set 2 | tabou
# Processing Record 13 of Set 2 | santa marta
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | huarmey
# Processing Record 16 of Set 2 | fort nelson
# Processing Record 17 of Set 2 | santa cruz
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | huadian
# Processing Record 20 of Set 2 | port hedland
# Processing Record 21 of Set 2 | bejar
# Processing Record 22 of Set 2 | port macquarie
# Processing Record 23 of Set 2 | pevek
# Processing Record 24 of Set 2 | lasa
# Processing Record 25 of Set 2 | koslan
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | ulladulla
# Processing Record 28 of Set 2 | nioro
# Processing Record 29 of Set 2 | ornskoldsvik
# Processing Record 30 of Set 2 | xining
# Processing Record 31 of Set 2 | udachnyy
# Processing Record 32 of Set 2 | montrose
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | victoria
# Processing Record 35 of Set 2 | hami
# Processing Record 36 of Set 2 | akonolinga
# Processing Record 37 of Set 2 | sopotnica
# Processing Record 38 of Set 2 | senanga
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | marystown
# Processing Record 41 of Set 2 | monte carmelo
# Processing Record 42 of Set 2 | sept-iles
# Processing Record 43 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 2 | mikonos
# City not found. Skipping...
# Processing Record 45 of Set 2 | champerico
# Processing Record 46 of Set 2 | cabo san lucas
# Processing Record 47 of Set 2 | touros
# Processing Record 48 of Set 2 | egvekinot
# Processing Record 49 of Set 2 | miles city
# Processing Record 50 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 3 | bredasdorp
# Processing Record 2 of Set 3 | los llanos de aridane
# Processing Record 3 of Set 3 | marsabit
# Processing Record 4 of Set 3 | olhao
# Processing Record 5 of Set 3 | zeya
# Processing Record 6 of Set 3 | matagami
# Processing Record 7 of Set 3 | nouakchott
# Processing Record 8 of Set 3 | nouadhibou
# Processing Record 9 of Set 3 | roma
# Processing Record 10 of Set 3 | new norfolk
# Processing Record 11 of Set 3 | honningsvag
# Processing Record 12 of Set 3 | gamboula
# Processing Record 13 of Set 3 | kahului
# Processing Record 14 of Set 3 | kitgum
# Processing Record 15 of Set 3 | anori
# Processing Record 16 of Set 3 | kibala
# Processing Record 17 of Set 3 | olafsvik
# Processing Record 18 of Set 3 | avarua
# Processing Record 19 of Set 3 | tuktoyaktuk
# Processing Record 20 of Set 3 | barabai
# Processing Record 21 of Set 3 | yellowknife
# Processing Record 22 of Set 3 | ferkessedougou
# Processing Record 23 of Set 3 | butaritari
# Processing Record 24 of Set 3 | sambava
# Processing Record 25 of Set 3 | nizhnyaya omka
# Processing Record 26 of Set 3 | aksu
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | mao
# Processing Record 29 of Set 3 | sillanwali
# Processing Record 30 of Set 3 | georgetown
# Processing Record 31 of Set 3 | vila franca do campo
# Processing Record 32 of Set 3 | rengo
# Processing Record 33 of Set 3 | muros
# Processing Record 34 of Set 3 | ryotsu
# Processing Record 35 of Set 3 | likasi
# Processing Record 36 of Set 3 | nanortalik
# Processing Record 37 of Set 3 | tatarsk
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | green river
# Processing Record 40 of Set 3 | riyadh
# Processing Record 41 of Set 3 | zyryanka
# Processing Record 42 of Set 3 | poya
# Processing Record 43 of Set 3 | saint-francois
# Processing Record 44 of Set 3 | faanui
# Processing Record 45 of Set 3 | bom jesus
# Processing Record 46 of Set 3 | san pedro
# Processing Record 47 of Set 3 | amga
# Processing Record 48 of Set 3 | maputo
# Processing Record 49 of Set 3 | batticaloa
# Processing Record 50 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 4 | san angelo
# Processing Record 2 of Set 4 | caravelas
# Processing Record 3 of Set 4 | grindavik
# Processing Record 4 of Set 4 | waw
# Processing Record 5 of Set 4 | tigil
# Processing Record 6 of Set 4 | dikson
# Processing Record 7 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | ilhabela
# Processing Record 10 of Set 4 | dianopolis
# City not found. Skipping...
# Processing Record 11 of Set 4 | loksa
# Processing Record 12 of Set 4 | zhenhai
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | kalmunai
# Processing Record 15 of Set 4 | allanmyo
# City not found. Skipping...
# Processing Record 16 of Set 4 | madera
# Processing Record 17 of Set 4 | anisoc
# Processing Record 18 of Set 4 | pelym
# Processing Record 19 of Set 4 | usinsk
# Processing Record 20 of Set 4 | arraial do cabo
# Processing Record 21 of Set 4 | waipawa
# Processing Record 22 of Set 4 | lata
# Processing Record 23 of Set 4 | rudsar
# Processing Record 24 of Set 4 | padang
# Processing Record 25 of Set 4 | husavik
# Processing Record 26 of Set 4 | mankera
# Processing Record 27 of Set 4 | avera
# Processing Record 28 of Set 4 | beringovskiy
# Processing Record 29 of Set 4 | brae
# Processing Record 30 of Set 4 | ponta do sol
# Processing Record 31 of Set 4 | tutoia
# Processing Record 32 of Set 4 | acuna
# City not found. Skipping...
# Processing Record 33 of Set 4 | bambanglipuro
# Processing Record 34 of Set 4 | bubaque
# Processing Record 35 of Set 4 | komsomolskiy
# Processing Record 36 of Set 4 | houma
# Processing Record 37 of Set 4 | hithadhoo
# Processing Record 38 of Set 4 | beira
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4 | abilene
# Processing Record 41 of Set 4 | half moon bay
# Processing Record 42 of Set 4 | maningrida
# Processing Record 43 of Set 4 | saldanha
# Processing Record 44 of Set 4 | phalombe
# Processing Record 45 of Set 4 | heihe
# Processing Record 46 of Set 4 | khatanga
# Processing Record 47 of Set 4 | palauig
# Processing Record 48 of Set 4 | cam ranh
# Processing Record 49 of Set 4 | correntina
# Processing Record 50 of Set 4 | rafsanjan
# Processing Record 1 of Set 5 | moundou
# Processing Record 2 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 5 | vanavara
# Processing Record 4 of Set 5 | kruisfontein
# Processing Record 5 of Set 5 | manggar
# Processing Record 6 of Set 5 | berlevag
# Processing Record 7 of Set 5 | abbeville
# Processing Record 8 of Set 5 | saint-augustin
# Processing Record 9 of Set 5 | labuhan
# Processing Record 10 of Set 5 | chuy
# Processing Record 11 of Set 5 | merauke
# Processing Record 12 of Set 5 | flin flon
# Processing Record 13 of Set 5 | kirkuk
# Processing Record 14 of Set 5 | fort wellington
# Processing Record 15 of Set 5 | cochabamba
# Processing Record 16 of Set 5 | ambilobe
# Processing Record 17 of Set 5 | san patricio
# Processing Record 18 of Set 5 | namtsy
# Processing Record 19 of Set 5 | portland
# Processing Record 20 of Set 5 | sola
# Processing Record 21 of Set 5 | moerai
# Processing Record 22 of Set 5 | vaini
# Processing Record 23 of Set 5 | longyearbyen
# Processing Record 24 of Set 5 | palora
# Processing Record 25 of Set 5 | ilulissat
# Processing Record 26 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 5 | sao domingos
# Processing Record 28 of Set 5 | nchelenge
# Processing Record 29 of Set 5 | deputatskiy
# Processing Record 30 of Set 5 | luderitz
# Processing Record 31 of Set 5 | cacak
# Processing Record 32 of Set 5 | abu dhabi
# Processing Record 33 of Set 5 | sao felix do xingu
# Processing Record 34 of Set 5 | ouro preto do oeste
# Processing Record 35 of Set 5 | obudovac
# Processing Record 36 of Set 5 | hammerfest
# Processing Record 37 of Set 5 | aklavik
# Processing Record 38 of Set 5 | maniitsoq
# Processing Record 39 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 5 | jinka
# Processing Record 41 of Set 5 | dalvik
# Processing Record 42 of Set 5 | glasgow
# Processing Record 43 of Set 5 | auch
# Processing Record 44 of Set 5 | arawa
# Processing Record 45 of Set 5 | manono
# Processing Record 46 of Set 5 | savalou
# Processing Record 47 of Set 5 | cherskiy
# Processing Record 48 of Set 5 | bathsheba
# Processing Record 49 of Set 5 | abnub
# Processing Record 50 of Set 5 | san vicente
# Processing Record 1 of Set 6 | fare
# Processing Record 2 of Set 6 | bardiyah
# Processing Record 3 of Set 6 | thai binh
# Processing Record 4 of Set 6 | neiafu
# Processing Record 5 of Set 6 | hofn
# Processing Record 6 of Set 6 | aksha
# Processing Record 7 of Set 6 | quatre cocos
# Processing Record 8 of Set 6 | sugar hill
# Processing Record 9 of Set 6 | wyndham
# Processing Record 10 of Set 6 | pacific grove
# Processing Record 11 of Set 6 | mount gambier
# Processing Record 12 of Set 6 | erenhot
# Processing Record 13 of Set 6 | srednekolymsk
# Processing Record 14 of Set 6 | peterhead
# Processing Record 15 of Set 6 | odlabari
# Processing Record 16 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 6 | kaele
# Processing Record 18 of Set 6 | talnakh
# Processing Record 19 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 6 | lazaro cardenas
# Processing Record 21 of Set 6 | ibra
# Processing Record 22 of Set 6 | leningradskiy
# Processing Record 23 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 6 | adrar
# Processing Record 25 of Set 6 | katyr-yurt
# Processing Record 26 of Set 6 | spanish town
# Processing Record 27 of Set 6 | ballstad
# City not found. Skipping...
# Processing Record 28 of Set 6 | necochea
# Processing Record 29 of Set 6 | nantucket
# Processing Record 30 of Set 6 | staroutkinsk
# Processing Record 31 of Set 6 | praia da vitoria
# Processing Record 32 of Set 6 | salalah
# Processing Record 33 of Set 6 | klaksvik
# Processing Record 34 of Set 6 | thompson
# Processing Record 35 of Set 6 | kokhma
# Processing Record 36 of Set 6 | salinopolis
# Processing Record 37 of Set 6 | karratha
# Processing Record 38 of Set 6 | laguna
# Processing Record 39 of Set 6 | comodoro rivadavia
# Processing Record 40 of Set 6 | lingao
# Processing Record 41 of Set 6 | guerrero negro
# Processing Record 42 of Set 6 | weligama
# Processing Record 43 of Set 6 | ransang
# Processing Record 44 of Set 6 | warrington
# Processing Record 45 of Set 6 | kaitangata
# Processing Record 46 of Set 6 | el calvario
# Processing Record 47 of Set 6 | bengkulu
# Processing Record 48 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 6 | upernavik
# Processing Record 50 of Set 6 | codrington
# Processing Record 1 of Set 7 | barillas
# Processing Record 2 of Set 7 | balkanabat
# Processing Record 3 of Set 7 | dalby
# Processing Record 4 of Set 7 | boddam
# Processing Record 5 of Set 7 | walvis bay
# Processing Record 6 of Set 7 | itaqui
# Processing Record 7 of Set 7 | esperance
# Processing Record 8 of Set 7 | zafra
# Processing Record 9 of Set 7 | norman wells
# Processing Record 10 of Set 7 | saint-philippe
# Processing Record 11 of Set 7 | rancho cordova
# Processing Record 12 of Set 7 | axim
# Processing Record 13 of Set 7 | blagoyevo
# Processing Record 14 of Set 7 | janauba
# Processing Record 15 of Set 7 | lipari
# Processing Record 16 of Set 7 | alyangula
# Processing Record 17 of Set 7 | porbandar
# Processing Record 18 of Set 7 | los chiles
# Processing Record 19 of Set 7 | carbonia
# Processing Record 20 of Set 7 | bambous virieux
# Processing Record 21 of Set 7 | astara
# Processing Record 22 of Set 7 | wanning
# Processing Record 23 of Set 7 | ancud
# Processing Record 24 of Set 7 | pajapan
# Processing Record 25 of Set 7 | port blair
# Processing Record 26 of Set 7 | clyde river
# Processing Record 27 of Set 7 | havre-saint-pierre
# Processing Record 28 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 7 | misratah
# Processing Record 31 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 7 | kuryk
# Processing Record 33 of Set 7 | genhe
# Processing Record 34 of Set 7 | leninskiy
# Processing Record 35 of Set 7 | ismailia
# Processing Record 36 of Set 7 | batsfjord
# Processing Record 37 of Set 7 | atasu
# Processing Record 38 of Set 7 | brignoles
# Processing Record 39 of Set 7 | port hardy
# Processing Record 40 of Set 7 | provideniya
# Processing Record 41 of Set 7 | athabasca
# Processing Record 42 of Set 7 | manadhoo
# Processing Record 43 of Set 7 | sorland
# Processing Record 44 of Set 7 | rocha
# Processing Record 45 of Set 7 | bonthe
# Processing Record 46 of Set 7 | batagay
# Processing Record 47 of Set 7 | evensk
# Processing Record 48 of Set 7 | alofi
# Processing Record 49 of Set 7 | moron
# Processing Record 50 of Set 7 | amahai
# Processing Record 1 of Set 8 | mahebourg
# Processing Record 2 of Set 8 | zonguldak
# Processing Record 3 of Set 8 | westport
# Processing Record 4 of Set 8 | cervo
# Processing Record 5 of Set 8 | ampanihy
# Processing Record 6 of Set 8 | kingston
# Processing Record 7 of Set 8 | alice springs
# Processing Record 8 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 8 | romanovo
# Processing Record 10 of Set 8 | storforshei
# Processing Record 11 of Set 8 | berekum
# Processing Record 12 of Set 8 | mehamn
# Processing Record 13 of Set 8 | meulaboh
# Processing Record 14 of Set 8 | quepos
# Processing Record 15 of Set 8 | taybad
# Processing Record 16 of Set 8 | las cruces
# Processing Record 17 of Set 8 | turukhansk
# Processing Record 18 of Set 8 | damietta
# Processing Record 19 of Set 8 | lorengau
# Processing Record 20 of Set 8 | colares
# Processing Record 21 of Set 8 | yerbogachen
# Processing Record 22 of Set 8 | palmer
# Processing Record 23 of Set 8 | dali
# Processing Record 24 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 8 | winslow
# Processing Record 26 of Set 8 | tonneins
# Processing Record 27 of Set 8 | mandera
# Processing Record 28 of Set 8 | vichuga
# Processing Record 29 of Set 8 | serenje
# Processing Record 30 of Set 8 | collie
# Processing Record 31 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 8 | narsaq
# Processing Record 33 of Set 8 | umea
# Processing Record 34 of Set 8 | oranjestad
# Processing Record 35 of Set 8 | taltal
# Processing Record 36 of Set 8 | bundaberg
# Processing Record 37 of Set 8 | nizwa
# Processing Record 38 of Set 8 | haapiti
# Processing Record 39 of Set 8 | nara
# Processing Record 40 of Set 8 | kieta
# Processing Record 41 of Set 8 | itaituba
# Processing Record 42 of Set 8 | manta
# Processing Record 43 of Set 8 | santa lucia
# Processing Record 44 of Set 8 | katsuura
# Processing Record 45 of Set 8 | seoul
# Processing Record 46 of Set 8 | marawi
# Processing Record 47 of Set 8 | fortuna
# Processing Record 48 of Set 8 | pisco
# Processing Record 49 of Set 8 | aswan
# Processing Record 50 of Set 8 | beloha
# Processing Record 1 of Set 9 | baoding
# Processing Record 2 of Set 9 | marsaxlokk
# Processing Record 3 of Set 9 | hohoe
# Processing Record 4 of Set 9 | dingle
# Processing Record 5 of Set 9 | molchanovo
# Processing Record 6 of Set 9 | urumqi
# Processing Record 7 of Set 9 | weyburn
# Processing Record 8 of Set 9 | samana
# Processing Record 9 of Set 9 | anadyr
# Processing Record 10 of Set 9 | mangaluru
# Processing Record 11 of Set 9 | mandurah
# Processing Record 12 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 13 of Set 9 | bondo
# Processing Record 14 of Set 9 | honiara
# Processing Record 15 of Set 9 | luena
# Processing Record 16 of Set 9 | bonavista
# Processing Record 17 of Set 9 | parras
# City not found. Skipping...
# Processing Record 18 of Set 9 | naze
# Processing Record 19 of Set 9 | ondjiva
# Processing Record 20 of Set 9 | arlit
# Processing Record 21 of Set 9 | karonga
# Processing Record 22 of Set 9 | varnamo
# Processing Record 23 of Set 9 | torbay
# Processing Record 24 of Set 9 | mackenzie
# Processing Record 25 of Set 9 | acajutla
# Processing Record 26 of Set 9 | baiyin
# Processing Record 27 of Set 9 | severo-kurilsk
# Processing Record 28 of Set 9 | college
# Processing Record 29 of Set 9 | bahir dar
# Processing Record 30 of Set 9 | strezhevoy
# Processing Record 31 of Set 9 | aviles
# Processing Record 32 of Set 9 | thaba-tseka
# Processing Record 33 of Set 9 | qaqortoq
# Processing Record 34 of Set 9 | ugoofaaru
# Processing Record 35 of Set 9 | jijiga
# Processing Record 36 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 9 | belaya gora
# Processing Record 38 of Set 9 | margate
# Processing Record 39 of Set 9 | isangel
# Processing Record 40 of Set 9 | paamiut
# Processing Record 41 of Set 9 | ambulu
# Processing Record 42 of Set 9 | maua
# Processing Record 43 of Set 9 | dargaville
# Processing Record 44 of Set 9 | sorong
# Processing Record 45 of Set 9 | zhigansk
# Processing Record 46 of Set 9 | iqaluit
# Processing Record 47 of Set 9 | roald
# Processing Record 48 of Set 9 | san cristobal
# Processing Record 49 of Set 9 | hambantota
# Processing Record 50 of Set 9 | invermere
# Processing Record 1 of Set 10 | kavieng
# Processing Record 2 of Set 10 | mayumba
# Processing Record 3 of Set 10 | penzance
# Processing Record 4 of Set 10 | redmond
# Processing Record 5 of Set 10 | kungurtug
# Processing Record 6 of Set 10 | moskovskiy
# Processing Record 7 of Set 10 | rockland
# Processing Record 8 of Set 10 | verkhnevilyuysk
# Processing Record 9 of Set 10 | gamba
# Processing Record 10 of Set 10 | kavaratti
# Processing Record 11 of Set 10 | capitao poco
# Processing Record 12 of Set 10 | miandoab
# Processing Record 13 of Set 10 | gat
# Processing Record 14 of Set 10 | inhambane
# Processing Record 15 of Set 10 | treinta y tres
# Processing Record 16 of Set 10 | charyshskoye
# Processing Record 17 of Set 10 | kurchum
# Processing Record 18 of Set 10 | datong
# Processing Record 19 of Set 10 | geraldton
# Processing Record 20 of Set 10 | catacamas
# Processing Record 21 of Set 10 | narrabri
# Processing Record 22 of Set 10 | moree
# Processing Record 23 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 10 | doctor cecilio baez
# Processing Record 26 of Set 10 | kendal
# Processing Record 27 of Set 10 | mogadishu
# Processing Record 28 of Set 10 | priekule
# Processing Record 29 of Set 10 | ler
# Processing Record 30 of Set 10 | mawlaik
# Processing Record 31 of Set 10 | ulaangom
# Processing Record 32 of Set 10 | baillif
# Processing Record 33 of Set 10 | jaisalmer
# Processing Record 34 of Set 10 | itarema
# Processing Record 35 of Set 10 | newport
# Processing Record 36 of Set 10 | perth
# Processing Record 37 of Set 10 | xinmin
# Processing Record 38 of Set 10 | sakakah
# Processing Record 39 of Set 10 | souillac
# Processing Record 40 of Set 10 | tripoli
# Processing Record 41 of Set 10 | curuguaty
# Processing Record 42 of Set 10 | omboue
# Processing Record 43 of Set 10 | wainwright
# Processing Record 44 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 45 of Set 10 | ust-koksa
# Processing Record 46 of Set 10 | shalinskoye
# Processing Record 47 of Set 10 | sale
# Processing Record 48 of Set 10 | inirida
# Processing Record 49 of Set 10 | wajir
# Processing Record 50 of Set 10 | port augusta
# Processing Record 1 of Set 11 | tateyama
# Processing Record 2 of Set 11 | killybegs
# Processing Record 3 of Set 11 | chapais
# Processing Record 4 of Set 11 | batagay-alyta
# Processing Record 5 of Set 11 | mareeba
# Processing Record 6 of Set 11 | cidreira
# Processing Record 7 of Set 11 | alenquer
# Processing Record 8 of Set 11 | tura
# Processing Record 9 of Set 11 | alta floresta
# Processing Record 10 of Set 11 | kenai
# Processing Record 11 of Set 11 | mbaiki
# Processing Record 12 of Set 11 | coihaique
# Processing Record 13 of Set 11 | kulhudhuffushi
# Processing Record 14 of Set 11 | cayenne
# Processing Record 15 of Set 11 | rajula
# Processing Record 16 of Set 11 | boyuibe
# Processing Record 17 of Set 11 | luganville
# Processing Record 18 of Set 11 | luzhou
# Processing Record 19 of Set 11 | point fortin
# Processing Record 20 of Set 11 | te anau
# Processing Record 21 of Set 11 | loei
# Processing Record 22 of Set 11 | oshawa
# Processing Record 23 of Set 11 | hobyo
# Processing Record 24 of Set 11 | vardo
# Processing Record 25 of Set 11 | hualmay
# Processing Record 26 of Set 11 | pochutla
# Processing Record 27 of Set 11 | tadine
# Processing Record 28 of Set 11 | harper
# Processing Record 29 of Set 11 | jacareacanga
# Processing Record 30 of Set 11 | arman
# Processing Record 31 of Set 11 | araouane
# Processing Record 32 of Set 11 | dromolaxia
# Processing Record 33 of Set 11 | kralendijk
# Processing Record 34 of Set 11 | inuvik
# Processing Record 35 of Set 11 | iquique
# Processing Record 36 of Set 11 | maragheh
# Processing Record 37 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 38 of Set 11 | puerto madero
# Processing Record 39 of Set 11 | gombe
# Processing Record 40 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 11 | aripuana
# Processing Record 42 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 43 of Set 11 | constitucion
# Processing Record 44 of Set 11 | miyazu
# Processing Record 45 of Set 11 | tazovskiy
# Processing Record 46 of Set 11 | sitangkai
# Processing Record 47 of Set 11 | sydney
# Processing Record 48 of Set 11 | dombarovskiy
# Processing Record 49 of Set 11 | umm lajj
# Processing Record 50 of Set 11 | hayato
# City not found. Skipping...
# Processing Record 1 of Set 12 | hirara
# Processing Record 2 of Set 12 | pervomayskoye
# Processing Record 3 of Set 12 | clarence town
# Processing Record 4 of Set 12 | nabire
# Processing Record 5 of Set 12 | negombo
# Processing Record 6 of Set 12 | hamilton
# Processing Record 7 of Set 12 | colinas
# Processing Record 8 of Set 12 | verkhoyansk
# Processing Record 9 of Set 12 | saint-joseph
# Processing Record 10 of Set 12 | tartus
# Processing Record 11 of Set 12 | ossora
# Processing Record 12 of Set 12 | haifa
# Processing Record 13 of Set 12 | huayucachi
# Processing Record 14 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 12 | stephenville
# Processing Record 16 of Set 12 | bartica
# Processing Record 17 of Set 12 | pizhanka
# Processing Record 18 of Set 12 | seymchan
# Processing Record 19 of Set 12 | challans
# Processing Record 20 of Set 12 | cassilandia
# Processing Record 21 of Set 12 | kant
# Processing Record 22 of Set 12 | san lazaro
# Processing Record 23 of Set 12 | tomatlan
# Processing Record 24 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 12 | cap malheureux
# Processing Record 26 of Set 12 | carmelo
# Processing Record 27 of Set 12 | imeni poliny osipenko
# Processing Record 28 of Set 12 | marzuq
# Processing Record 29 of Set 12 | wilmington
# Processing Record 30 of Set 12 | batemans bay
# Processing Record 31 of Set 12 | conakry
# Processing Record 32 of Set 12 | kloulklubed
# Processing Record 33 of Set 12 | ancona
# Processing Record 34 of Set 12 | trincomalee
# Processing Record 35 of Set 12 | vanimo
# Processing Record 36 of Set 12 | lompoc
# Processing Record 37 of Set 12 | beya
# Processing Record 38 of Set 12 | riverton
# Processing Record 39 of Set 12 | dondo
# Processing Record 40 of Set 12 | kaura namoda
# Processing Record 41 of Set 12 | najran
# Processing Record 42 of Set 12 | hailar
# Processing Record 43 of Set 12 | belmonte
# Processing Record 44 of Set 12 | fukue
# Processing Record 45 of Set 12 | birnin kebbi
# Processing Record 46 of Set 12 | byron bay
# Processing Record 47 of Set 12 | maun
# Processing Record 48 of Set 12 | nemuro
# Processing Record 49 of Set 12 | santa isabel do rio negro
# Processing Record 50 of Set 12 | magdagachi
# Processing Record 1 of Set 13 | pital
# Processing Record 2 of Set 13 | broken hill
# Processing Record 3 of Set 13 | xinzhou
# Processing Record 4 of Set 13 | haines junction
# Processing Record 5 of Set 13 | kermanshah
# Processing Record 6 of Set 13 | lac-megantic
# Processing Record 7 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 8 of Set 13 | kabanjahe
# Processing Record 9 of Set 13 | talas
# Processing Record 10 of Set 13 | biak
# Processing Record 11 of Set 13 | kutum
# Processing Record 12 of Set 13 | tukrah
# Processing Record 13 of Set 13 | pemangkat
# Processing Record 14 of Set 13 | xuddur
# Processing Record 15 of Set 13 | dakar
# Processing Record 16 of Set 13 | zhangye
# Processing Record 17 of Set 13 | yeppoon
# Processing Record 18 of Set 13 | kosiv
# Processing Record 19 of Set 13 | boulder city
# Processing Record 20 of Set 13 | dolores
# Processing Record 21 of Set 13 | tommot
# Processing Record 22 of Set 13 | eyl
# Processing Record 23 of Set 13 | xianyang
# Processing Record 24 of Set 13 | derazhnya
# Processing Record 25 of Set 13 | pemberton
# Processing Record 26 of Set 13 | liusha
# Processing Record 27 of Set 13 | cuencame
# Processing Record 28 of Set 13 | namatanai
# Processing Record 29 of Set 13 | christchurch
# Processing Record 30 of Set 13 | karpathos
# Processing Record 31 of Set 13 | altoona
# Processing Record 32 of Set 13 | nanyuki
# Processing Record 33 of Set 13 | mnogovershinnyy
# Processing Record 34 of Set 13 | jizan
# Processing Record 35 of Set 13 | taoudenni
# Processing Record 36 of Set 13 | torbat-e jam
# Processing Record 37 of Set 13 | samarai
# Processing Record 38 of Set 13 | le moule
# Processing Record 39 of Set 13 | port hawkesbury
# Processing Record 40 of Set 13 | bar-le-duc
# Processing Record 41 of Set 13 | loviisa
# Processing Record 42 of Set 13 | san
# Processing Record 43 of Set 13 | manokwari
# Processing Record 44 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 45 of Set 13 | itanhem
# Processing Record 46 of Set 13 | elko
# Processing Record 47 of Set 13 | valparaiso
# Processing Record 48 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 49 of Set 13 | myitkyina
# Processing Record 50 of Set 13 | shirwal
# Processing Record 1 of Set 14 | chimbote
# Processing Record 2 of Set 14 | morro bay
# Processing Record 3 of Set 14 | griffith
# Processing Record 4 of Set 14 | aksay
# Processing Record 5 of Set 14 | ust-nera
# Processing Record 6 of Set 14 | moryakovskiy zaton
# Processing Record 7 of Set 14 | luckenwalde
# Processing Record 8 of Set 14 | muzhi
# Processing Record 9 of Set 14 | svetlogorsk
# Processing Record 10 of Set 14 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 11 of Set 14 | wa
# City not found. Skipping...
# Processing Record 12 of Set 14 | richards bay
# Processing Record 13 of Set 14 | koumac
# Processing Record 14 of Set 14 | kerema
# Processing Record 15 of Set 14 | shakawe
# Processing Record 16 of Set 14 | espoo
# Processing Record 17 of Set 14 | tiznit
# Processing Record 18 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 14 | gbarnga
# Processing Record 20 of Set 14 | shingu
# Processing Record 21 of Set 14 | tromso
# Processing Record 22 of Set 14 | sawakin
# Processing Record 23 of Set 14 | hella
# Processing Record 24 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 14 | high level
# Processing Record 26 of Set 14 | stanilesti
# Processing Record 27 of Set 14 | fort smith
# Processing Record 28 of Set 14 | tocopilla
# Processing Record 29 of Set 14 | kendari
# Processing Record 30 of Set 14 | chernyshevskiy
# Processing Record 31 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 14 | fukagawa
# Processing Record 33 of Set 14 | kupang
# Processing Record 34 of Set 14 | filadelfia
# Processing Record 35 of Set 14 | chemax
# Processing Record 36 of Set 14 | port lincoln
# Processing Record 37 of Set 14 | solenzo
# Processing Record 38 of Set 14 | carutapera
# Processing Record 39 of Set 14 | la grande
# Processing Record 40 of Set 14 | nagarote
# Processing Record 41 of Set 14 | smithers
# Processing Record 42 of Set 14 | chapleau
# Processing Record 43 of Set 14 | vao
# Processing Record 44 of Set 14 | dwarka
# Processing Record 45 of Set 14 | svobodnyy
# Processing Record 46 of Set 14 | klyuchi
# Processing Record 47 of Set 14 | praya
# Processing Record 48 of Set 14 | babu
# Processing Record 49 of Set 14 | escanaba
# Processing Record 50 of Set 14 | la tuque
# Processing Record 1 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 2 of Set 15 | ellisras
# Processing Record 3 of Set 15 | raton
# Processing Record 4 of Set 15 | pitimbu
# Processing Record 5 of Set 15 | lahaina
# Processing Record 6 of Set 15 | gravdal
# Processing Record 7 of Set 15 | buchanan
# Processing Record 8 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 9 of Set 15 | nata
# Processing Record 10 of Set 15 | awjilah
# Processing Record 11 of Set 15 | methoni
# Processing Record 12 of Set 15 | ponta delgada
# Processing Record 13 of Set 15 | henties bay
# Processing Record 14 of Set 15 | neuquen
# Processing Record 15 of Set 15 | masuguru
# Processing Record 16 of Set 15 | raudeberg
# Processing Record 17 of Set 15 | suihua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 665

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hobart      AU -42.8794  147.3294     66.22        59          20
# 1      Nikolskoye      RU  59.7035   30.7861     26.80        84          10
# 2           Mecca      SA  21.4267   39.8261     76.12        72           0
# 3      Sao Filipe      CV  14.8961  -24.4956     78.71        76         100
# 4       Busselton      AU -33.6500  115.3333     53.89        68          87
# 5           Abony      HU  47.1899   20.0048     47.12        97         100
# 6          Hasaki      JP  35.7333  140.8333     63.28        55          92
# 7            Nome      US  64.5011 -165.4064     35.67        93         100
# 8    Punta Arenas      CL -53.1500  -70.9167     50.11        57          20
# 9  Ribeira Grande      PT  38.5167  -28.7000     56.77        71          17
#
#    Wind Speed Current Description
# 0        9.22          few clouds
# 1        6.24           clear sky
# 2        3.58           clear sky
# 3        2.39     overcast clouds
# 4       20.94     overcast clouds
# 5        6.91     overcast clouds
# 6       10.92     overcast clouds
# 7       11.50          light rain
# 8       17.27          few clouds
# 9        5.99          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hobart      AU -42.8794  147.3294     66.22        59          20
# 1      Nikolskoye      RU  59.7035   30.7861     26.80        84          10
# 2           Mecca      SA  21.4267   39.8261     76.12        72           0
# 3      Sao Filipe      CV  14.8961  -24.4956     78.71        76         100
# 4       Busselton      AU -33.6500  115.3333     53.89        68          87
# 5           Abony      HU  47.1899   20.0048     47.12        97         100
# 6          Hasaki      JP  35.7333  140.8333     63.28        55          92
# 7            Nome      US  64.5011 -165.4064     35.67        93         100
# 8    Punta Arenas      CL -53.1500  -70.9167     50.11        57          20
# 9  Ribeira Grande      PT  38.5167  -28.7000     56.77        71          17
#
#    Wind Speed Current Description
# 0        9.22          few clouds
# 1        6.24           clear sky
# 2        3.58           clear sky
# 3        2.39     overcast clouds
# 4       20.94     overcast clouds
# 5        6.91     overcast clouds
# 6       10.92     overcast clouds
# 7       11.50          light rain
# 8       17.27          few clouds
# 9        5.99          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
csv_weather_file = "weatherpy_database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(csv_weather_file, index=False)
